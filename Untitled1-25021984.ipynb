# %%
print("Hello World!")
# Out:
# Hello World!

# %%
name=input("Nhập tên:" )
print("Xin chào",name)
# Out:
# Nhập tên: TÚ
# Xin chào TÚ

# %%
a=int(input("a="))
b=int(input("b="))
print("Tổng:",a+b)
print("Hiệu:",a-b)
print("Tích:",a*b)
if b!=0:
    print("phép chia có phần nguyên:",a//b,"và phần dư:",a%b)
    print("phép chia thực lấy 2 chữ số phần thập phân:",int(a/b*100)/100)
else:
    print("Không thể chia cho 0")
# Out:
# a= 50
# b= 3
# Tổng: 53
# Hiệu: 47
# Tích: 150
# phép chia có phần nguyên: 16 và phần dư: 2
# phép chia thực lấy 2 chữ số phần thập phân: 16.66

# %%
a1,b1,c1,a2,b2,a3=map(float,input("6 đầu điểm:").split())
diem=(a1+b1+c1+(a2+b2)*2+a3*3)/10
print("Điểm trung bình:",int(diem*10)/10)
# Out:
# 6 đầu điểm: 9 9.99 8.88 7.77 6.66 10
# Điểm trung bình: 8.6

# %%
a,b=map(int,input("nhập 2 số a và b:").split())
print("a^b=",a**b)
# Out:
# nhập 2 số a và b: 3 4
# a^b= 81

# %%
thuong=input("Chữ cái thường:")
print("Mã unicode:",ord(thuong))
print("Kí tự hoa",thuong.upper())
# Out:
# Chữ cái thường: n
# Mã unicode: 110
# Kí tự hoa N

# %%
A=((13**2)*3)+5
B=13**2*3+5
print("A=",A)
print("B=",B)
# Out:
# A= 512
# B= 512

# %%
C=float(input("Độ C:"))
F=9/5*C+32
print("Độ F:",round(F,2))
# Out:
# Độ C: 36.6
# Độ F: 97.88

# %%
x=float(input("Giá đồng hồ (USD):"))
tien=x*(1+0.3+0.1)+10
print("Tổng số tiền Đạt trả:",round(tien,2),"USD")
# Out:
# Giá đồng hồ (USD): 10.77
# Tổng số tiền Đạt trả: 25.08 USD

# %%
ten=input("Tên 3 người:").split()
print("Hi",ten[2],",",ten[1],"and",ten[0])
# Out:
# Tên 3 người: mèo gà chó
# Hi chó , gà and mèo

# %%
h=float(input("Nhập số giờ:"))
m=float(input("Nhập số phút:"))
s=3600*h+60*m
print("Số giây:",s)
# Out:
# Nhập số giờ: 1
# Nhập số phút: 0.5
# Số giây: 3630.0

# %%
n=int(input("Nhập độ dài cạnh của rubik"))
m=n**2*6
print("Số miếng dán:",m)
# Out:
# Nhập độ dài cạnh của rubik 3
# Số miếng dán: 54

# %%
a=int(input("Số nguyên dương a="))
b=int(input("Số nguyên dương b="))
if a>0 and b>0:
    c=(a*b)%10
    print("Hàng đơn vị của tích:",c)
else:
    print("Nhập số nguyên dương")
# Out:
# Số nguyên dương a= 14
# Số nguyên dương b= 18
# Hàng đơn vị của tích: 2

# %%
a=float(input("a="))
b=float(input("b="))
a,b=b,a
print("a=",a,"b=",b)
# Out:
# a= 10
# b= 9
# a= 9.0 b= 10.0

# %%
n=int(input("số nguyên dương n="))
if n>0:
    sao=n*6*(n-1)+1
    print("Số sao thứ",n,"là",sao)
else:
    print("Nhập số nguyên dương")
# Out:
# số nguyên dương n= 3
# Số sao thứ 3 là 37

# %%
print("Sping\nSummer\nAutumn\nWinter")
# Out:
# Sping
# Summer
# Autumn
# Winter

# %%
print("*")
print("***")
print("******")
# Out:
# *
# ***
# ******

# %%
print("### ##   ### ###")
print(" #  # #   #   #")
print(" #  #  #  #   #")
print(" #  # #   #   #")
print(" #  ##    #   #")
# Out:
# ### ##   ### ###
#  #  # #   #   #
#  #  #  #  #   #
#  #  # #   #   #
#  #  ##    #   #

# %%
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
print("Hello, world\n"*10)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
